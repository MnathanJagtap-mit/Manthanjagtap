# %% [markdown]
# <a href="https://colab.research.google.com/github/MnathanJagtap-mit/Manthanjagtap/blob/main/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

data = [1, 3, 4, 4, 5, 5, 6, 7, 8, 8, 8, 9, 10]

plt.hist(data, bins=5, edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')

plt.show()
